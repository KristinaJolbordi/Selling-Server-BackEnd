-- %% [markdown]
-- # [SellingDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [SellingDB]    Script Date: 9/26/2023 5:02:34 PM ******/
CREATE DATABASE [SellingDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'SellingDB', FILENAME = N'C:\Users\Saba\SellingDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'SellingDB_log', FILENAME = N'C:\Users\Saba\SellingDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [SellingDB] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [SellingDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [SellingDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [SellingDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [SellingDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [SellingDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [SellingDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [SellingDB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [SellingDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [SellingDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [SellingDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [SellingDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [SellingDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [SellingDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [SellingDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [SellingDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [SellingDB] SET  DISABLE_BROKER 
GO
ALTER DATABASE [SellingDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [SellingDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [SellingDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [SellingDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [SellingDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [SellingDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [SellingDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [SellingDB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [SellingDB] SET  MULTI_USER 
GO
ALTER DATABASE [SellingDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [SellingDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [SellingDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [SellingDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [SellingDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [SellingDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [SellingDB] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
USE [SellingDB]
GO

-- %%
/****** Object:  Table [dbo].[__EFMigrationsHistory]    Script Date: 9/26/2023 5:02:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__EFMigrationsHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK___EFMigrationsHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cities]

-- %%
/****** Object:  Table [dbo].[Cities]    Script Date: 9/26/2023 5:02:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cities](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nchar](20) NOT NULL,
 CONSTRAINT [PK_Cities] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Countries]

-- %%
/****** Object:  Table [dbo].[Countries]    Script Date: 9/26/2023 5:02:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Countries](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nchar](15) NOT NULL,
 CONSTRAINT [PK_Countries] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Customers]

-- %%
/****** Object:  Table [dbo].[Customers]    Script Date: 9/26/2023 5:02:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Customers](
	[Id] [int] NOT NULL,
	[FirstName] [nchar](15) NOT NULL,
	[LastName] [nchar](15) NOT NULL,
	[GenderId] [int] IDENTITY(1,1) NOT NULL,
	[PersonalNumber] [varchar](9) NOT NULL,
	[BirthDate] [date] NOT NULL,
	[CityId] [int] NOT NULL,
	[CountryId] [int] NOT NULL,
	[Email] [varchar](64) NOT NULL,
	[Adress] [nchar](30) NOT NULL,
	[PN] [varchar](10) NOT NULL,
 CONSTRAINT [PK_Customers] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CustomersPhoneNumbers]

-- %%
/****** Object:  Table [dbo].[CustomersPhoneNumbers]    Script Date: 9/26/2023 5:02:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CustomersPhoneNumbers](
	[Id] [nchar](10) NOT NULL,
	[PhoneTypeId] [int] NOT NULL,
	[PhoneNumber] [varchar](9) NOT NULL,
	[CustomerId] [int] IDENTITY(1,1) NOT NULL,
	[IsMain] [nchar](10) NOT NULL,
 CONSTRAINT [PK_CustomersPhoneNumbers] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CustomersRelationships]

-- %%
/****** Object:  Table [dbo].[CustomersRelationships]    Script Date: 9/26/2023 5:02:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CustomersRelationships](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RelationshipTypeId] [int] NOT NULL,
	[StartCustomerId] [int] NOT NULL,
	[EndCustomerId] [int] NOT NULL,
	[Comment] [nchar](20) NOT NULL,
 CONSTRAINT [PK_CustomersRelationships] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Gender]

-- %%
/****** Object:  Table [dbo].[Gender]    Script Date: 9/26/2023 5:02:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Gender](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nchar](10) NOT NULL,
 CONSTRAINT [PK_Gender] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrderItems]

-- %%
/****** Object:  Table [dbo].[OrderItems]    Script Date: 9/26/2023 5:02:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrderItems](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[OrderId] [int] NOT NULL,
	[ProductId] [int] NOT NULL,
	[UnitPrice] [decimal](10, 2) NOT NULL,
	[Quantity] [int] NOT NULL,
	[IsDiscounted] [int] NOT NULL,
	[DiscountPrice] [decimal](10, 2) NOT NULL,
 CONSTRAINT [PK_OrderItems] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Orders]

-- %%
/****** Object:  Table [dbo].[Orders]    Script Date: 9/26/2023 5:02:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Orders](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrderDate] [date] NOT NULL,
	[OrderNumber] [int] NOT NULL,
	[CustomerId] [int] NOT NULL,
	[TotalAmount] [int] NOT NULL,
 CONSTRAINT [PK_Orders] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PhoneTypes]

-- %%
/****** Object:  Table [dbo].[PhoneTypes]    Script Date: 9/26/2023 5:02:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PhoneTypes](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nchar](10) NOT NULL,
 CONSTRAINT [PK_PhoneTypes] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProductCategories]

-- %%
/****** Object:  Table [dbo].[ProductCategories]    Script Date: 9/26/2023 5:02:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProductCategories](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [nchar](10) NOT NULL,
	[Name] [nchar](20) NOT NULL,
 CONSTRAINT [PK_ProductCategories] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Products]

-- %%
/****** Object:  Table [dbo].[Products]    Script Date: 9/26/2023 5:02:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Products](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [nchar](10) NOT NULL,
	[Name] [nchar](20) NOT NULL,
	[CategoryId] [int] NOT NULL,
	[AgeRecommendation] [smallint] NOT NULL,
 CONSTRAINT [PK_Products] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RelationshipTypes]

-- %%
/****** Object:  Table [dbo].[RelationshipTypes]    Script Date: 9/26/2023 5:02:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RelationshipTypes](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nchar](20) NOT NULL,
 CONSTRAINT [PK_RelationshipTypes] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Suppliers]

-- %%
/****** Object:  Table [dbo].[Suppliers]    Script Date: 9/26/2023 5:02:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Suppliers](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CompanyCode] [nchar](10) NOT NULL,
	[CompanyName] [nchar](20) NOT NULL,
	[CompanyFullName] [nchar](30) NOT NULL,
	[CityId] [int] NOT NULL,
	[CountryId] [int] NOT NULL,
	[Phone] [varchar](9) NOT NULL,
	[Fax] [varchar](9) NOT NULL,
	[Email] [varchar](64) NOT NULL,
	[Address] [nchar](50) NOT NULL,
	[TotalQuantity] [int] NOT NULL,
 CONSTRAINT [PK_Suppliers] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Units]

-- %%
/****** Object:  Table [dbo].[Units]    Script Date: 9/26/2023 5:02:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Units](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nchar](10) NOT NULL,
	[ShortName] [nchar](5) NOT NULL,
 CONSTRAINT [PK_Units] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Warehouse]

-- %%
/****** Object:  Table [dbo].[Warehouse]    Script Date: 9/26/2023 5:02:34 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Warehouse](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OperationDate] [date] NOT NULL,
	[DocNumber] [nchar](25) NOT NULL,
	[ProductId] [int] NOT NULL,
	[SupplierId] [int] NOT NULL,
	[UnitId] [int] NOT NULL,
	[Quantity] [int] NOT NULL,
	[ExpiryDate] [date] NOT NULL,
	[UnitPrice] [decimal](10, 2) NOT NULL,
	[RealizationPrice] [decimal](10, 2) NOT NULL,
 CONSTRAINT [PK_Warehouse] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Suppliers__Total__14270015]

-- %%
ALTER TABLE [dbo].[Suppliers] ADD  DEFAULT ((0)) FOR [TotalQuantity]
GO

-- %% [markdown]
-- # [FK_Warehouse_Units]

-- %%
ALTER TABLE [dbo].[Warehouse]  WITH CHECK ADD  CONSTRAINT [FK_Warehouse_Units] FOREIGN KEY([UnitId])
REFERENCES [dbo].[Units] ([Id])
GO
ALTER TABLE [dbo].[Warehouse] CHECK CONSTRAINT [FK_Warehouse_Units]
GO

-- %% [markdown]
-- # [SellingDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [SellingDB] SET  READ_WRITE 
GO
